# %% [markdown]
# # Week 4: Machine Learning Engineering
#
# ## Overview
# Build **reliable ML systems**, not just models. Focus on ML engineering practices for production.
#
# ### Learning Objectives
# - ML problem framing
# - Feature engineering pipelines
# - Supervised learning
# - Bias-variance tradeoff
# - Evaluation metrics
# - Data leakage & validation
#
# ### Project
# Customer Churn Prediction System
#
# ---

# %% [markdown]
# ## Part 1: ML Problem Framing
#
# ### TODO 1.1: Problem Framing

# %%
from typing import Dict, List
import pandas as pd
import numpy as np

class MLProblemFramework:
    '''Framework for framing ML problems.'''
    
    def __init__(self, business_problem: str):
        self.business_problem = business_problem
        self.ml_problem_type = None  # classification, regression, clustering
        self.success_metrics = []
        self.constraints = []
    
    def define_ml_problem(self) -> Dict:
        '''Define the ML problem from business problem.'''
        # TODO: Implement problem definition
        pass

# TODO: Frame a customer churn problem

# %% [markdown]
# ## Part 2: Feature Engineering
#
# ### TODO 2.1: Feature Pipeline

# %%
class FeatureEngineer:
    '''Build feature engineering pipelines.'''
    
    def __init__(self):
        self.transformers = []
    
    def fit_transform(self, df: pd.DataFrame) -> pd.DataFrame:
        '''Fit and transform features.'''
        # TODO: Implement feature engineering
        pass

# TODO: Create features for churn prediction

# %% [markdown]
# ## Part 3: Model Training & Evaluation
#
# ### TODO 3.1: Train ML Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

class MLPipeline:
    '''Production ML pipeline.'''
    
    def __init__(self):
        self.model = None
        self.feature_engineer = FeatureEngineer()
    
    def train(self, X, y):
        '''Train the model.'''
        # TODO: Implement training with validation
        pass
    
    def evaluate(self, X_test, y_test) -> Dict:
        '''Evaluate model performance.'''
        # TODO: Calculate metrics
        pass

# TODO: Train and evaluate churn model

# %% [markdown]
# ## Part 4: Week 4 Project - Customer Churn Prediction
#
# ### TODO 4.1: Complete Churn Prediction System

# %%
class ChurnPredictionSystem:
    '''Production-grade churn prediction system.'''
    
    def __init__(self):
        self.pipeline = MLPipeline()
    
    def build(self, data: pd.DataFrame):
        '''Build the complete system.'''
        # TODO: Implement end-to-end system
        # 1. Feature engineering
        # 2. Train-test split
        # 3. Model training
        # 4. Evaluation
        # 5. Deploy for predictions
        pass

# TODO: Build and test the system

# %% [markdown]
# ## Summary
#
# ### What You've Learned
# - ML problem framing
# - Feature engineering
# - Model training & evaluation
# - Production ML pipelines
#
# ### Next: Deep Learning & Vision (Week 5)
#
# ---
